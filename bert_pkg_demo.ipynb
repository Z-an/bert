# %%
from embeddings import getEmbeddings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f18f84dc487d> in <module>
# ----> 1 from embeddings import getEmbeddings
#
# ~/Desktop/metadata/bert/embeddings.py in <module>
#       1 from bert_embedding import BertEmbedding
# ----> 2 from bert.utils import zomatoPreprocess
#       3
#       4 import numpy as np
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'bert'

# %%
names,cuisines,urls,embeds,bagofberts = getEmbeddings(city='sydney',n_restaurants=100,cuisines=False)

# %%
from plot import plot_pc

# %%
plot_pc(embeds,names)

# %%
from clustering import agglomerative,getFlatLabels

# %%
l = agglomerative(embeds,names,viz=True)
# Out:
# Cophenetic correlation: 0.6321397110077369

# %%
l, m, s, t = getFlatLabels(l,embeds,names=names,urls=urls)
# Out:
# Large clusters n:
# 1
#
# Medium clusters n:
# 1
#
# Small clusters n:
# 6
#
# Tiny clusters n:
# 49
